# %%
import pandas as pd
import plotly.express as px

# Crear la figura y los ejes 3D
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Función de actualización para la animación
def update(frame):
    ax.view_init(elev=10., azim=frame)

# Scatter plot 1 con color rojo
sc1 = ax.scatter(data_red[ind_gesto4, 2], data_red[ind_gesto4, 3], data_red[ind_gesto4, 4], c = 'r', label='Scatter Plot 1')

# Scatter plot 2 con color azul
sc2 = ax.scatter(data_red[ind_gesto5, 2], data_red[ind_gesto5, 3], data_red[ind_gesto5, 4], c = 'g', label='Scatter Plot 2')

# Scatter plot 3 con color verde
sc3 =ax.scatter(data_red[ind_gesto6, 2], data_red[ind_gesto6, 3], data_red[ind_gesto6, 4], c = 'b', label='Scatter Plot 3')

# Agregar leyenda
ax.legend()

# Agregar etiquetas y título
ax.set_xlabel('Coordenada X')
ax.set_ylabel('Coordenada Y')
ax.set_zlabel('Coordenada Z')
ax.set_title('Scatter Plots en 3D con Coordenadas X, Y y Z')

# Crear animación
ani = FuncAnimation(fig, update, frames=np.arange(0, 360, 1), interval=50)

# Mostrar animación
plt.show()

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Scatter plot 1 con color rojo
sc1 = ax.scatter(data_red[ind_gesto4, 2], data_red[ind_gesto4, 3], c=data_red[ind_gesto4, 4], cmap='Blues', label='Scatter Plot 1')

# Scatter plot 2 con color azul
sc2 = ax.scatter(data_red[ind_gesto5, 2], data_red[ind_gesto5, 3], c=data_red[ind_gesto5, 4], cmap='Reds', label='Scatter Plot 2')

# Scatter plot 3 con color verde
sc3 =ax.scatter(data_red[ind_gesto6, 2], data_red[ind_gesto6, 3], c=data_red[ind_gesto6, 4], cmap='Oranges', label='Scatter Plot 3')

# Agregar barra de color
cbar = plt.colorbar(sc1, ax=ax, label='Coordenada Z')

# Agregar leyenda
ax.legend()

# Agregar etiquetas y título
ax.set_xlabel('Coordenada X')
ax.set_ylabel('Coordenada Y')
ax.set_title('Scatter Plots con Colores Diferentes')

# Mostrar el plot
plt.show()

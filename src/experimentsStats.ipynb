# %% [markdown]
# El objetivo de este script es acceder a los experimentos guardados en comet y calcular distintos valores estadísticos

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/repo_tesis/entorno_tesis_Molina"
# !source bin/activate
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/repo_tesis/entorno_tesis_Molina

# %%
# !pip install comet_ml
import numpy as np
from comet_ml import Experiment
from comet_ml.api import API, APIExperiment
import pandas as pd
# Out:
# Collecting comet_ml
#   Downloading comet_ml-3.41.0-py3-none-any.whl (648 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.9/648.9 kB 6.1 MB/s eta 0:00:00
# Collecting everett[ini]<3.2.0,>=1.0.1 (from comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (4.19.2)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.6 MB/s eta 0:00:00
# Collecting requests-toolbelt>=0.8.0 (from comet_ml)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.31.0)
# Collecting semantic-version>=2.8.0 (from comet_ml)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting sentry-sdk>=1.1.0 (from comet_ml)
#   Downloading sentry_sdk-2.1.1-py2.py3-none-any.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.3/277.3 kB 24.9 MB/s eta 0:00:00
# Collecting simplejson (from comet_ml)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (2.0.7)
# Collecting websocket-client<1.4.0,>=0.55.0 (from comet_ml)
#   Downloading websocket_client-1.3.3-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (1.14.1)
# Collecting wurlitzer>=1.0.2 (from comet_ml)
#   Downloading wurlitzer-3.1.0-py3-none-any.whl (8.4 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-0.22.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (979 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.1/979.1 kB 24.6 MB/s eta 0:00:00
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet_ml) (13.7.1)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet_ml) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet_ml) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Installing collected packages: everett, wurlitzer, websocket-client, simplejson, sentry-sdk, semantic-version, python-box, dulwich, configobj, requests-toolbelt, comet_ml
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.8.0
#     Uninstalling websocket-client-1.8.0:
#       Successfully uninstalled websocket-client-1.8.0
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# Successfully installed comet_ml-3.41.0 configobj-5.0.8 dulwich-0.22.1 everett-3.1.0 python-box-6.1.0 requests-toolbelt-1.0.0 semantic-version-2.10.0 sentry-sdk-2.1.1 simplejson-3.19.2 websocket-client-1.3.3 wurlitzer-3.1.0

# %%
# ejemplo de como acceder a las metricas de un experimento
api = API(api_key="ehXeElNypcj7Knar5zTmyjwSO")
x = api.get("manuelmolinach99/tesis-experimentos/e5041d3070fd40a884ac1e793204ace1")
metricas = x.get_metrics()
metricas = pd.DataFrame(metricas)

metricas
# Out:
#                     metricName         metricValue      timestamp  step epoch  \
# 0           sys.disk.root.used         26392698880  1712589499908  None  None
# 1                    precision  0.5960763834914086  1712589499556  None  None
# 2          sys.cpu.percent.avg                64.3  1712589499677  None  None
# 3                     accuracy  0.5747776130467013  1712589499556  None  None
# 4          sys.compute.overall                64.3  1712589499677  None  None
# 5            sys.ram.available         11700490240  1712589499677  None  None
# 6         sys.compute.utilized                55.8  1712589499677  None  None
# 7   sys.disk.root.percent.used                22.8  1712589499909  None  None
# 8                training_time  105.86380553245544  1712589499556  None  None
# 9                 sys.load.avg       1.68896484375  1712589499677  None  None
# 10                      recall  0.5747776130467013  1712589499556  None  None
# 11        sys.ram.percent.used                14.0  1712589499677  None  None
# 12               sys.ram.total         13609443328  1712589499677  None  None
# 13                sys.ram.used          1908953088  1712589499677  None  None
#
#    runContext               offset
# 0        None -1057628061204247061
# 1        None -8582226770363069900
# 2        None -8600102698254366653
# 3        None -6256096212159881258
# 4        None  -764227816679346260
# 5        None -4192679596919150655
# 6        None -9061336380072758720
# 7        None -3499222424417263269
# 8        None -7745435762607381717
# 9        None  -117598347625169731
# 10       None -5301134920922316286
# 11       None -7897364610415679757
# 12       None -8963557928527686112
# 13       None -3639145640250553297

# %% [markdown]
# Voy a extraer las métricas de los experimentos asociados al *baseline*.

# %%
# Creo un objeto api, a traves del cual voy a acceder a todos los experimentos
api = API(api_key="ehXeElNypcj7Knar5zTmyjwSO")

# mlp separando por repeticion
exp_bsl = [
    'aa882196c7e3415e9c07827120fc9352'
    '628106495f034d4cba9c21103c8b3cf3'
    '2f46e2bfb3fa4e0dbb94e2f7339b0d80'
    '22a0a059dae446e2b3302718994902ab'
    'f98706d4dee4457c9d6c3d5239b36c5a'
    '5865b969a7f44cbc9641c42df58bb69c'
    'd8f04aea3b944de5a560d5e4899d6b2c'
    'a653d14480204e12bec4bfd18407e8e5'
    'c02a776b87e241cb956534b6fa104b42'
    '21180dddd3cf470b86bb5b5597dbd6c1'
]

# Me interesa guardar accuracy, recall, precision y training time
accuracy = []
recall = []
precision = []
training_time = []

for i in range(len(exp_bsl)):
  x = api.get("manuelmolinach99/tesis-experimentos/" + exp_bsl[i])
  metricas_aux = x.get_metrics()
  metricas_aux = pd.DataFrame(metricas)
  fila_accuracy = metricas.loc[metricas['metricName'] == 'accuracy']
  fila_recall = metricas.loc[metricas['metricName'] == 'recall']
  fila_precision = metricas.loc[metricas['metricName'] == 'precision']
  fila_training_time = metricas.loc[metricas['metricName'] == 'training time']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ff43430483f1> in <cell line: 24>()
#      24 for i in range(len(exp_bsl)):
#      25   x = api.get("manuelmolinach99/tesis-experimentos/" + exp_bsl[i])
# ---> 26   metricas_aux = x.get_metrics()
#      27   metricas_aux = pd.DataFrame(metricas)
#      28   fila_accuracy = metricas.loc[metricas['metricName'] == 'accuracy']
#
# AttributeError: 'NoneType' object has no attribute 'get_metrics'

# %%
api = API(api_key="ehXeElNypcj7Knar5zTmyjwSO")

lista_exp = api.get_experiments(workspace = 'manuelmolinach99', project_name='tesis-experimentos', pattern='baseline_mlp_sep_sub')
nombres = []
metricas = []
for i in range(len(lista_exp)):
# lista_exp[0].get_metrics()
  nombres.append(lista_exp[i].get_name())
  metricas.append(lista_exp[i].get_metrics(metric=None))
print(nombres)


# Hacer una lista con todos los nombres y ahi filtro para quedarme con los indices de los que quiero, luego busco en lista_exp
# Out:
# ['baseline_mlp_sep_sub1_testing', 'baseline_mlp_sep_sub2_testing', 'baseline_mlp_sep_sub3_testing', 'baseline_mlp_sep_sub4_testing', 'baseline_mlp_sep_sub5_testing', 'baseline_mlp_sep_sub6_testing', 'baseline_mlp_sep_sub7_testing', 'baseline_mlp_sep_sub8_testing', 'baseline_mlp_sep_sub9_testing', 'baseline_mlp_sep_sub10_testing']

# %%
# hago una lista con las metricas que quiero extraer
nombres_metricas = ['accuracy', 'recall', 'precision', 'training_time']
accuracy_list = []  # 10 valores de accuracy, uno por experimento/sujeto
recall_list = []  # 10 valores de accuracy, uno por experimento/sujeto
precision_list = []  # 10 valores de accuracy, uno por experimento/sujeto
training_time_list = []  # 10 valores de accuracy, uno por experimento/sujeto
sujeto_list = list(np.arange(1, 11))

cant_experimentos = 10

for i in range(cant_experimentos):
  for dato in metricas[i]:
      # Verificar si el valor de 'metricName' es 'accuracy'
      if dato["metricName"] == "accuracy":
          # Si es así, guardar el valor correspondiente
          accuracy_list.append(dato["metricValue"])
      elif dato["metricName"] == "recall":
          # Si es así, guardar el valor correspondiente
          recall_list.append(dato["metricValue"])
      elif dato["metricName"] == "precision":
          # Si es así, guardar el valor correspondiente
          precision_list.append(dato["metricValue"])
      elif dato["metricName"] == "training_time":
          # Si es así, guardar el valor correspondiente
          training_time_list.append(dato["metricValue"])

# Crear un DataFrame con los datos
df = pd.DataFrame({
    'sujeto': sujeto_list,
    'accuracy': accuracy_list,
    'recall': recall_list,
    'precision': precision_list,
    'training_time': training_time_list
})

# %%
df.head(10)
# Out:
#    sujeto             accuracy               recall            precision  \
# 0       1   0.2641237855343649   0.2641237855343649  0.25986499954738923
# 1       2   0.3332317537711412   0.3332317537711412  0.34317820577991104
# 2       3  0.26580226904376014  0.26580226904376014  0.28088168106259576
# 3       4   0.2693525179856115   0.2693525179856115   0.2885440684586679
# 4       5  0.29042192793347704  0.29042192793347704  0.29065890491368496
# 5       6  0.17527272727272727  0.17527272727272727   0.1815379360044061
# 6       7   0.2479387514723204   0.2479387514723204  0.23785384738675763
# 7       8  0.24338381520575186  0.24338381520575186  0.25964176223527635
# 8       9   0.2767131687873678   0.2767131687873678   0.3201536093921782
# 9      10  0.16763957491393505  0.16763957491393505  0.18384262226429343
#
#         training_time
# 0  1051.2417647838593
# 1  1045.7656354904175
# 2   983.2798192501068
# 3   982.9093279838562
# 4   982.8541722297668
# 5  1009.1441130638123
# 6   983.3552398681641
# 7    968.689859867096
# 8  1042.9293115139008
# 9  1042.8974916934967
